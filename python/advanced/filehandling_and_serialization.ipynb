# %% [markdown]
# Types of file:
# 1. Text file
# 2. Binary File

# %%
#opening file in write mode and writing test data
f = open('assets/sample.txt', 'w')
f.write('This is test file!!!')
f.close()

# %%
# writing multiple lines to a file
f = open('assets/sample1.txt', 'w')
f.write('This is test file!!!\n')
f.write('This is second line!!!\n')
f.close()

# %%
# appending to the file
f = open('assets/sample1.txt', 'a')
f.write('This is appended line!!!\n')
f.write('This is another appended line!!!\n')
f.close()

# %%
# reading from the file
f = open('assets/sample1.txt', 'r')
print(f.read())  # read the entire file
# Out:
# This is test file!!!
# This is second line!!!
# This is appended line!!!
# This is another appended line!!!

# %%
# read line by line (readline and print new line)
f = open('assets/sample1.txt', 'r')
print(f.readline(), end='')  # read first line
print(f.readline(), end='')  # read second line
# Out:
# This is test file!!!
#
# This is second line!!!

# %%
# read line by line (This a bug because it reads two lines at a time)
f = open('assets/sample1.txt', 'r')
while f.readline() != '':
    print(f.readline(), end='')
# Out:
# This is second line!!!
# This is appended line!!!

# %%
# read from the file in chuck (\n is also one character)
f = open('assets/sample1.txt', 'r')
print(f.read(9))
print(f.read(9))
print(f.read(9000))
# Out:
# This is t
# est file!
# !!
# This is second line!!!
# This is appended line!!!
# This is another appended line!!!

# %% [markdown]
# ### Seek and tell:
# tell: show current position of the file pointer in bytes
# seek: move the file pointer ro specific position

# %%
with open('assets/sample1.txt', 'r') as f:
    print(f.tell()) # get current position in the file
    print(f.read(9))  # read first 9 characters
    print(f.tell())  # get current position in the file
# Out:
# 0
# This is t
# 9

# %%
# working with binary files
with open('assets/image.png', 'rb') as f:
    data = f.read(10)  # read first 9 characters (this will not work for binary files)
    print(type(data))  # <class 'bytes'>
    print(data) # prints the binary data as characters
    print(data.hex())  # prints the hexadecimal respresentation of the binary data
    
    for byte in data:
        print(byte, end=' ')
# Out:
# <class 'bytes'>
# b'\x89PNG\r\n\x1a\n\x00\x00'
# 89504e470d0a1a0a0000
# 137 80 78 71 13 10 26 10 0 0

# %%
# read the file in binary mode and print each byte
with open('assets/image.png', 'rb') as f:
    byte = f.read(1)  # read one byte at a time
    while byte:
        print(byte.hex(), end=' ')
        byte = f.read(1)  # read next byte
# Out:
# 89 50 4e 47 0d 0a 1a 0a 00 00 00 0d 49 48 44 52 00 00 05 b0 00 00 02 6f 08 06 00 00 00 aa 17 f7 cf 00 00 00 01 73 52 47 42 00 ae ce 1c e9 00 00 00 04 67 41 4d 41 00 00 b1 8f 0b fc 61 05 00 00 00 09 70 48 59 73 00 00 0e c3 00 00 0e c3 01 c7 6f a8 64 00 00 ff a5 49 44 41 54 78 5e ec dd 09 58 54 55 ff 07 f0 ef bf 34 50 13 70 03 97 c4 d1 5c 13 43 53 33 15 13 c3 a2 30 33 45 53 b4 45 2d 53 d1 e2 a5 4c a5 34 51 2b b4 2c a2 10 35 df 44 4d 45 32 24 2d 29 de 24 31 51 5f d7 24 71 37 25 cc 05 dc 00 37 48 eb fd df e5 cc 30 33 cc 0c db 0c 0c f0 fd 3c cf e8 b9 67 66 2e 77 39 f7 dc 7b 7f f7 cc 
88 88 88 a8 e2 b0 0b 11 22 22 22 22 22 22 22 22 22 22 b2 4b 0c 60 13 11 11 11 11 11 11 11 11 11 91 5d 62 00 9b 88 88 88 88 88 88 88 88 88 88 ec 12 03 d8 44 44 44 44 44 44 44 44 44 44 64 97 18 c0 26 22 22 22 22 22 22 22 22 22 22 bb c4 00 36 11 11 11 11 11 11 11 11 11 11 d9 25 06 b0 89 88 88 88 88 88 88 88 88 88 c8 2e 31 80 4d 44 44 44 44 44 44 44 44 44 44 76 89 01 6c 22 22 22 22 22 22 22 22 22 22 b2 4b 0c 60 13 11 11 11 11 11 11 11 11 11 91 5d 62 00 9b 88 88 88 88 88 88 88 88 88 88 ec 12 03 d8 44 44 44 44 44 44 44 44 44 44 64 97 18 c0 26 22 22 22 22 22 22 22 22 22 22 bb c4 00 36 11 11 11 11 11 11 11 11 11 11 d9 25 06 b0 a9 72 6a 3e 08 75 da 7a 8a 09 22 22 22 22 22 22 22 22 22 aa 8a fe af 6e 3d b7 ff 89 34 34 9a 56 48 3b 78 40 4c 11 d9 97 fb 3f bd 02 bf 0e 8e a8 73 b7 c8 f8 7d 39 e6 8d 0f 14 13 a4 1a 0f cf cf c7 c3 5d da 46 79 97 8f e1 5c 66 1e f2 4e ac c0 ef 89 c9 e2 fd ca af dd 92 9b 18 7c bf 98 30 e9 28 e2 fb 3f 84 63 62 aa 90 c7 13 30 6e 9a 37 1a 88 49 53 2e ef 0c c1 d2 99 11 62 8a 88 88 88 88 88 88 88 88 2a 0a 5b 60 53 a5 51 a3 96 5e f0 9a cc 90 b6 51 d3 f6 e8 d8 b6 3d ba f6 1c 84 81 cf 0e c7 63 5e 6c a9 4e 44 44 44 44 44 44 44 44 95 53 b5 0a 60 37 98 7b 1e d3 37 df 14 af c3 f0 d4 88 37 26 ee d7 cb bf 82 7e fe 22 df 98 dc 7 ...

# %%
# fun exercise mofifying the magic number of a PNG file
# png files start with the magic number 89 50 4E 47 0D 0A 1A 0A
with open('assets/image.png', 'rb') as f:
    data = f.read()  # read the entire file
    modified_data = bytearray(data)  
    modified_data[0] = 0x88  # change the first byte of the magic number
    with open('assets/image_modified.png', 'wb') as f_out:
        f_out.write(modified_data)

# %% [markdown]
# ### serializing and deserializing
# Serialization = Converting an object into a byte stream
# Deserialization = Converting a byte stream into an object

# %%
# serialization the list
import json

l = [1, 2, 3, 4, 5]

with open('assets/sample.json', 'w') as f:
    json.dump(l, f)

# %%
# serializing the dictionary into json
import json

d = {'name': 'John', 'age': 30, 'city': 'New York'}

with open('assets/sample.json', 'w') as f:
    json.dump(d, f, indent=4)  # write the dictionary to the file in JSON format

# %%
# deserializing the json file
with open('assets/sample.json', 'r') as f:
    data = json.load(f)  # read the JSON data from the file
    print(data)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
# serializing a tuple to JSON format
a = (1, 2, 3, 4, 5)
json_data = json.dumps(a)  # serialize the tuple to JSON format
print(json_data)  # prints the JSON representation of the tuple


b = {1,2,3,4,5} # set
# Out:
# [1, 2, 3, 4, 5]
